# %% [markdown]
# <a href="https://colab.research.google.com/github/sainik-khaddar/Python-Data-Analysis-EE/blob/main/EE_A_OFFLINE_LAB_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
resp=pd.read_csv('/content/SEC A RESPONSES) - Form responses 1.csv')

# %%
resp.head()
# Out:
#              Timestamp  ... HAVE U SHIFTED TO KOLKATA ?
# 0  21/11/2021 15:38:09  ...      I live in Kolkata only
# 1  21/11/2021 15:38:24  ...                          No
# 2  21/11/2021 15:38:57  ...      I live in Kolkata only
# 3  21/11/2021 15:39:13  ...      I live in Kolkata only
# 4  21/11/2021 15:39:42  ...      I live in Kolkata only
#
# [5 rows x 9 columns]

# %%
resp.shape
# Out:
# (55, 9)

# %%
vacc=pd.read_csv('/content/VACCINATION SURVEY EE A (Responses) - Form responses 1.csv')

# %%
vacc.head()
# Out:
#              Timestamp  ...  Have u taken VACCINATION 2ND DOSE?
# 0  22/11/2021 14:23:11  ...                                 Yes
# 1  22/11/2021 14:23:11  ...                                  No
# 2  22/11/2021 14:25:24  ...                                  No
# 3  22/11/2021 14:26:29  ...                                 Yes
# 4  22/11/2021 14:26:33  ...                                 Yes
#
# [5 rows x 4 columns]

# %%
vacc.shape
# Out:
# (57, 4)

# %%
vacc['Have u taken VACCINATION 1ST DOSE?'].value_counts()
# Out:
# Yes    57
# Name: Have u taken VACCINATION 1ST DOSE?, dtype: int64

# %%
vacc['Have u taken VACCINATION 2ND DOSE?'].value_counts()
# Out:
# Yes    40
# No     17
# Name: Have u taken VACCINATION 2ND DOSE?, dtype: int64

# %%
resp['Can you attend OFFLINE LAB CLASSES ?'].value_counts()
# Out:
# Yes,  I'll be there     48
# Sorry, can't make it     7
# Name: Can you attend OFFLINE LAB CLASSES ?, dtype: int64

# %%
final=resp[["Email address","Can you attend OFFLINE LAB CLASSES ?","MENTION YOUR FULL NAME :-","MENTION YOUR FULL EMAIL :-","MENTION YOUR FULL CONTACT NUM :-","CLASS ROLL NUMBER","HAVE U SHIFTED TO KOLKATA ?","FROM WHICH DISTRICT WILL U COME ?"]].merge(vacc[["CLASS ROLL NUMBER","Have u taken VACCINATION 1ST DOSE?","Have u taken VACCINATION 2ND DOSE?"]],on="CLASS ROLL NUMBER",how="left")

# %%
final.head()
# Out:
#               Email address  ... Have u taken VACCINATION 2ND DOSE?
# 0    sourishtito7@gmail.com  ...                                Yes
# 1   sirjantudust8@gmail.com  ...                                 No
# 2     rajsaha9876@gmail.com  ...                                Yes
# 3   anirbanm.1728@gmail.com  ...                                Yes
# 4  to.raghavsaini@gmail.com  ...                                Yes
#
# [5 rows x 10 columns]

# %%
final.isna()
# Out:
#     Email address  ...  Have u taken VACCINATION 2ND DOSE?
# 0           False  ...                               False
# 1           False  ...                               False
# 2           False  ...                               False
# 3           False  ...                               False
# 4           False  ...                               False
# 5           False  ...                               False
# 6           False  ...                               False
# 7           False  ...                               False
# 8           False  ...                               False
# 9           False  ...                               False
# 10          False  ...                               False
# 11          False  ...                               False
# 12          False  ...                               False
# 13          False  ...                               False
# 14          False  ...                               False
# ...

# %%
final.to_csv("EE_A Results FINAL.csv",index=False)
